# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\tableau files for portfolio\dataset\data\FashionDataset.csv")
data.head()
# Out:
#    Unnamed: 0    BrandName                                            Deatils  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='object')

# %%
data.rename(columns={"Deatils" : "Details"}, inplace = True)
data.tail()
# Out:
#        Unnamed: 0  BrandName  \
# 30753          21  swarovski
# 30754          22        Nan
# 30755          23     jewelz
# 30756          24    estelle
# 30757          25    estelle
#
#                                                  Details Sizes       MRP  \
# 30753            crystal stylish womens rodhium earrings   Nan       Nan
# 30754                                                Nan   Nan       Nan
# 30755                 ethnic gold plated jhumki earrings   Nan  Rs\n1839
# 30756  womens gold plated double line fancy white and...   Nan       Nan
# 30757  womens gold plated bridge designer mangalsutra...   Nan       Nan
#
#       SellPrice Discount         Category
# 30753      8950      Nan  Jewellery-Women
# 30754       Nan      Nan  Jewellery-Women
# 30755       643  65% off  Jewellery-Women
# 30756      2799      Nan  Jewellery-Women
# 30757      1899      Nan  Jewellery-Women

# %%
data.shape
# Out:
# (30758, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30758 non-null  int64
#  1   BrandName   30758 non-null  object
#  2   Details     30758 non-null  object
#  3   Sizes       30758 non-null  object
#  4   MRP         30758 non-null  object
#  5   SellPrice   30758 non-null  object
#  6   Discount    30758 non-null  object
#  7   Category    30758 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.9+ MB

# %%
data["Category"].value_counts()
# Out:
# Westernwear-Women           10374
# Indianwear-Women            10374
# Lingerie&Nightwear-Women     3354
# Footwear-Women               2574
# Watches-Women                1794
# Jewellery-Women              1794
# Fragrance-Women               494
# Name: Category, dtype: int64

# %%
data.loc[data["SellPrice"]=="Nan"].count()
# Out:
# Unnamed: 0    1183
# BrandName     1183
# Details       1183
# Sizes         1183
# MRP           1183
# SellPrice     1183
# Discount      1183
# Category      1183
# dtype: int64

# %%
data.loc[data["MRP"]=="Nan"].count()
# Out:
# Unnamed: 0    8208
# BrandName     8208
# Details       8208
# Sizes         8208
# MRP           8208
# SellPrice     8208
# Discount      8208
# Category      8208
# dtype: int64

# %%
data.replace("Nan", np.nan, inplace = True)
data.head()
# Out:
#    Unnamed: 0    BrandName                                            Details  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# ...

# %%
data.loc[data["Category"]=="Fragrance-Women"]
# Out:
#        Unnamed: 0                  BrandName  \
# 28470           0           antonio banderas
# 28471           1  united colors of benetton
# 28472           2            dolce & gabbana
# 28473           3                      guess
# 28474           4               paco rabanne
# ...           ...                        ...
# 28959          21                       plum
# 28960          22                        NaN
# 28961          23                  colour me
# 28962          24            dolce & gabbana
# 28963          25          narciso rodriguez
#
#                                                  Details Sizes       MRP  \
# 28470  womens the secret temptation deodorant spray 1...   NaN   Rs\n500
# 28471     sisterland green jasmine eau de toilette 80 ml   NaN  Rs\n2100
# 28472                      light blue eau intense 100 ml   NaN       NaN
# 28473                  mens 1981 eau de toilette - 100ml   NaN  Rs\n3990
# ...

# %%
data.drop(["MRP"], axis = 1, inplace = True)

# %%
data.isna().any()
# Out:
# Unnamed: 0    False
# BrandName      True
# Details        True
# Sizes          True
# SellPrice      True
# Discount       True
# Category      False
# dtype: bool

# %%
data.head()
# Out:
#    Unnamed: 0    BrandName                                            Details  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small       849  50% off
# 1                         Size:34,36,38,40      2449  30% off
# 2              Size:Large,X-Large,XX-Large       599  50% off
# 3          Size:Large,Medium,Small,X-Large      1379  40% off
# 4                   Size:26,28,30,32,34,36       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# ...

# %%
data.dropna(axis=0, how = "all", inplace = True)

# %%
data.head()
# Out:
#    Unnamed: 0    BrandName                                            Details  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small       849  50% off
# 1                         Size:34,36,38,40      2449  30% off
# 2              Size:Large,X-Large,XX-Large       599  50% off
# 3          Size:Large,Medium,Small,X-Large      1379  40% off
# 4                   Size:26,28,30,32,34,36       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# ...

# %%
data.rename(columns={"Unnamed: 0": "UnNamed"}, inplace = True)

# %%
data[data["UnNamed"]==22]
# Out:
#        UnNamed BrandName Details Sizes SellPrice Discount           Category
# 22          22       NaN     NaN   NaN       NaN      NaN  Westernwear-Women
# 48          22       NaN     NaN   NaN       NaN      NaN  Westernwear-Women
# 74          22       NaN     NaN   NaN       NaN      NaN  Westernwear-Women
# 100         22       NaN     NaN   NaN       NaN      NaN  Westernwear-Women
# 126         22       NaN     NaN   NaN       NaN      NaN  Westernwear-Women
# ...        ...       ...     ...   ...       ...      ...                ...
# 30650       22       NaN     NaN   NaN       NaN      NaN    Jewellery-Women
# 30676       22       NaN     NaN   NaN       NaN      NaN    Jewellery-Women
# 30702       22       NaN     NaN   NaN       NaN      NaN    Jewellery-Women
# 30728       22       NaN     NaN   NaN       NaN      NaN    Jewellery-Women
# 30754       22       NaN     NaN   NaN       NaN      NaN    Jewellery-Women
#
# [1183 rows x 7 columns]

# %%
data.dropna(axis = 0, thresh = 5, inplace = True)
data.head()
# Out:
#    UnNamed    BrandName                                            Details  \
# 0        0         life  solid cotton blend collar neck womens a-line d...
# 1        1         only  polyester peter pan collar womens blouson dres...
# 2        2      fratini  solid polyester blend wide neck womens regular...
# 3        3  zink london  stripes polyester sweetheart neck womens dress...
# 4        4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small       849  50% off
# 1                         Size:34,36,38,40      2449  30% off
# 2              Size:Large,X-Large,XX-Large       599  50% off
# 3          Size:Large,Medium,Small,X-Large      1379  40% off
# 4                   Size:26,28,30,32,34,36       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %%
data.isna().any()
# Out:
# UnNamed      False
# BrandName    False
# Details      False
# Sizes         True
# SellPrice    False
# Discount      True
# Category     False
# dtype: bool

# %%
a= data["Category"].value_counts()
a
# Out:
# Westernwear-Women           9975
# Indianwear-Women            9975
# Lingerie&Nightwear-Women    3225
# Footwear-Women              2475
# Watches-Women               1725
# Jewellery-Women             1725
# Fragrance-Women              475
# Name: Category, dtype: int64

# %%
a = data["Sizes"].str.split(',', n = 6, expand = True)
a.drop([6], axis =1, inplace = True)
a.head()
# Out:
#             0        1         2        3        4     5
# 0  Size:Large   Medium     Small  X-Large  X-Small  None
# 1     Size:34       36        38       40     None  None
# 2  Size:Large  X-Large  XX-Large     None     None  None
# 3  Size:Large   Medium     Small  X-Large     None  None
# 4     Size:26       28        30       32       34    36

# %%
data.drop(["Sizes"], axis =1, inplace = True)

# %%
data=data.merge(a, left_index=True, right_index=True)

# %%
data.reset_index()
# Out:
#        index  UnNamed           BrandName  \
# 0          0        0                life
# 1          1        1                only
# 2          2        2             fratini
# 3          3        3         zink london
# 4          4        4                life
# ...      ...      ...                 ...
# 29570  30752       20  shaya by caratlane
# 29571  30753       21           swarovski
# 29572  30755       23              jewelz
# 29573  30756       24             estelle
# 29574  30757       25             estelle
#
#                                                  Details SellPrice Discount  \
# 0      solid cotton blend collar neck womens a-line d...       849  50% off
# 1      polyester peter pan collar womens blouson dres...      2449  30% off
# 2      solid polyester blend wide neck womens regular...       599  50% off
# 3      stripes polyester sweetheart neck womens dress...      1379  40% off
# ...

# %%
data.drop(["UnNamed"], axis = 1, inplace = True)

# %%
data.rename(columns={0:"size0"}, inplace=True)

# %%
data["size0"]= data["size0"].str.replace("Size:", "")

# %%
data.shape
# data.drop(["0"], axis=1, inplace=True)
# Out:
# (29575, 11)

# %%
data.rename(columns={1:"size1", 2:"size2",3:"size3",4:"size4",5:"size5"}, inplace=True)

# %%
data.head()
# Out:
#      BrandName                                            Details SellPrice  \
# 0         life  solid cotton blend collar neck womens a-line d...       849
# 1         only  polyester peter pan collar womens blouson dres...      2449
# 2      fratini  solid polyester blend wide neck womens regular...       599
# 3  zink london  stripes polyester sweetheart neck womens dress...      1379
# 4         life  regular fit regular length denim womens jeans ...       849
#
#   Discount           Category  size0    size1     size2    size3    size4  \
# 0  50% off  Westernwear-Women  Large   Medium     Small  X-Large  X-Small
# 1  30% off  Westernwear-Women     34       36        38       40     None
# 2  50% off  Westernwear-Women  Large  X-Large  XX-Large     None     None
# 3  40% off  Westernwear-Women  Large   Medium     Small  X-Large     None
# 4  50% off  Westernwear-Women     26       28        30       32       34
#
#   size5
# 0  None
# 1  None
# 2  None
# 3  None
# 4    36

# %%
a = data.loc[data["Category"]=="Westernwear-Women"]["BrandName"].count()
b = data["BrandName"].count()
a
# Out:
# 9975

# %%
# b.plot(kind="bar", x=b, figsize=(40,10))

# %%
size = ["X-Large", "XX-Large", "XXX-Large"]

west_wear = data[(data["Category"]=="Westernwear-Women")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
ww1 = west_wear["BrandName"].count()
ww2=data.loc[data["Category"]=="Westernwear-Women"]["BrandName"].count()
ww1, ww2
# Out:
# (5089, 9975)

# %%
# y = np.array([5089, 4886])
# mylabels = ["+size", "medium size"]
# exp = [0.05,0]
# plt.pie(y, labels=mylabels, explode = exp)
# plt.legend()
# plt.show()

# %%
size = ["X-Large", "XX-Large", "XXX-Large"]

indian_wear = data[(data["Category"]=="Indianwear-Women")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
iw1=indian_wear["BrandName"].count()
iw2=data.loc[data["Category"]=="Indianwear-Women"]["BrandName"].count()
iw1,iw2
# Out:
# (5076, 9975)

# %%
# y = np.array([5089, 4899])
# mylabels = ["+size", "medium size"]
# exp = [0.05,0]
# plt.pie(y, labels=mylabels, explode = exp)
# plt.legend()
# plt.show()

# %%
size = ["X-Large", "XX-Large", "XXX-Large"]

brand = data[(data["BrandName"]=="global desi")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
brand
# Out:
#          BrandName                                            Details  \
# 1059   global desi            womens regular fit geometric top - sage
# 1614   global desi                womens self pattern tunic - mustard
# 2473   global desi           womens regular fit solid tunic - mustard
# 3286   global desi          womens regular fit floral tunic - mustard
# 3640   global desi  womens geometric v-neck fit and flare top - na...
# ...            ...                                                ...
# 19985  global desi  solid viscose round neck womens full length ku...
# 20001  global desi  printed polyester round neck womens regular ku...
# 20073  global desi  ethnic motifs boat neck womens polyester kurta...
# 20076  global desi                mandarin a line women kurtas - teal
# 20141  global desi  flared fit ankle length polyester womens festi...
#
#       SellPrice Discount           Category size0    size1     size2    size3  \
# ...

# %%
Selling_p = data["SellPrice"].astype(int)

# %%
data=data.merge(Selling_p, left_index=True, right_index=True)

# %%
data.drop(["SellPrice_x"], axis=True, inplace=True)

# %%
data["SellPrice_y"].dtype
# Out:
# dtype('int32')

# %%
y = np.array([5089, 4886])
mylabels = ["+size", "medium size"]
exp = [0.05,0]
plt.pie(y, labels=mylabels, explode = exp)
plt.legend()
plt.title("Western wear and Plus sizes")
plt.show()

# %%
y = np.array([5089, 4899])
mylabels = ["+size", "medium size"]
exp = [0.05,0]
plt.pie(y, labels=mylabels, explode = exp)
plt.legend()
plt.title("Indian wear and Plus Sizes")
plt.show()

# %%
accessibility = data[(data["SellPrice_y"]<=500)
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]

acc = accessibility["BrandName"].count()


b_500 = data.loc[data["SellPrice_y"]<=500]
below_500=b_500["BrandName"].count()
acc, below_500
# Out:
# (1608, 3943)

# %%
x = ["+Size clothes below Rs.500"]
y1 = np.array([1608])
y2 = np.array([3943])
y3= np.subtract(below_500,acc)
plt.bar(x, y3, 0.4, bottom=y1, label=  "total below Rs.500" )
plt.bar(x,y1, 0.4, label= "+ size clothes < Rs.500"  )

plt.xlabel("")
plt.ylabel("units")
plt.legend()
plt.show()

# %%
v = data[(data["BrandName"]=="vastranand")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
v1=v["BrandName"].count()
v2= data.loc[data["BrandName"]=="vastranand"]["BrandName"].count()
v2, v1
# Out:
# (1543, 0)

# %%
zl = data[(data["BrandName"]=="zink london")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
zl=zl["BrandName"].count()
zl2 = data.loc[data["BrandName"]=="zink london"]["BrandName"].count()
zl, zl2
# Out:
# (677, 918)

# %%
gd= data[(data["BrandName"]=="global desi")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
gd=gd["BrandName"].count()
gd2 = data.loc[data["BrandName"]=="global desi"]["BrandName"].count()
gd, gd2
# Out:
# (335, 889)

# %%
s = data[(data["BrandName"]=="stop")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
s=s["BrandName"].count()
s2 = data.loc[data["BrandName"]=="stop"]["BrandName"].count()
s,s2
# Out:
# (591, 884)

# %%
enamor = data[(data["BrandName"]=="enamor")
               & ((data["size0"].isin(size))
               | (data["size1"].isin(size))
               | (data["size2"].isin(size))
               | (data["size3"].isin(size))
               | (data["size4"].isin(size))
               | (data["size5"].isin(size)))]
enamor=enamor["BrandName"].count()
e2 = data.loc[data["BrandName"]=="enamor"]["BrandName"].count()
enamor,e2
# Out:
# (196, 790)

# %%
x = ["vastranand","zink london","global desi","stop","enamor"]
y1 = np.array([0, 677, 355, 591, 196])
y2=np.array([1543, 918, 889, 884, 790])

plt.bar(x, y1, label =" nos. of ' +size '  clothes ")
plt.bar(x, y2, bottom = y1 )
plt.figsize=(10,12)

plt.xlabel("Name of the brands")
plt.ylabel("units")
plt.legend()

plt.show()
